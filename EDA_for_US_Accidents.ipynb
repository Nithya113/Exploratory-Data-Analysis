# %% [markdown]
# #US Accident analysis

# %% [markdown]
# # Statements about Datasets
#
# 1.Are there more accidents in warmer or colder areas
#
# 2.Which 5 states have highest no of accidents? and
# how about capita?
#
# 3.This does not contain data about New York ( Since New York is in US)

# %% [markdown]
# # DATA PREPARATION AND CLEANING

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("US_Accidents_Dec21_updated.csv")

# %%
df
# Out:
#             ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0          A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1          A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2          A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3          A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4          A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# ...        ...       ...                  ...                  ...        ...
# 11401  A-11402         3  2016-06-12 15:19:03  2016-06-12 21:19:03  33.256390
# 11402  A-11403         2  2016-06-12 15:21:48  2016-06-12 21:21:48  34.005160
# 11403  A-11404         3  2016-06-12 15:24:37  2016-06-12 21:24:37  33.188415
# 11404  A-11405         2  2016-06-12 16:35:02  2016-06-12 22:35:02  33.882840
# 11405  A-11406         2  2016-06-12 14:51:49  2016-06-12 22:51:49  34.239110
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11406 entries, 0 to 11405
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     11406 non-null  object
#  1   Severity               11406 non-null  int64
#  2   Start_Time             11406 non-null  object
#  3   End_Time               11406 non-null  object
#  4   Start_Lat              11406 non-null  float64
#  5   Start_Lng              11406 non-null  float64
#  6   End_Lat                11406 non-null  float64
#  7   End_Lng                11406 non-null  float64
#  8   Distance(mi)           11406 non-null  float64
#  9   Description            11406 non-null  object
#  10  Number                 1822 non-null   float64
#  11  Street                 11406 non-null  object
#  12  Side                   11406 non-null  object
#  13  City                   11406 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  11406.000000  11406.000000  11406.000000  11406.000000  11406.000000
# mean       2.227512     35.860479   -116.366587     35.860700   -116.366496
# std        0.527092      2.324813     10.379960      2.325300     10.380362
# min        2.000000     32.543392   -123.526160     32.542490   -123.526160
# 25%        2.000000     33.965460   -121.783816     33.966964   -121.784567
# 50%        2.000000     34.239130   -118.281510     34.239370   -118.281515
# 75%        2.000000     37.824940   -117.697840     37.823860   -117.692170
# max        4.000000     41.964290    -80.005270     41.964290    -79.958150
#
#        Distance(mi)       Number  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  11406.000000   1822.00000    11274.000000     716.000000  11263.000000
# mean       0.576602   9255.61416       64.231799      30.725698     58.293705
# ...

# %%
numerics = ['int16','int32','int64','float16','float32','float64']
numeric_df = df.select_dtypes(include = numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
df.isnull() # viewing is null in the columns
# Out:
#           ID  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  End_Lat  \
# 0      False     False       False     False      False      False    False
# 1      False     False       False     False      False      False    False
# 2      False     False       False     False      False      False    False
# 3      False     False       False     False      False      False    False
# 4      False     False       False     False      False      False    False
# ...      ...       ...         ...       ...        ...        ...      ...
# 11401  False     False       False     False      False      False    False
# 11402  False     False       False     False      False      False    False
# 11403  False     False       False     False      False      False    False
# 11404  False     False       False     False      False      False    False
# 11405  False     False       False     False      False      False    False
#
# ...

# %%
df.isnull().sum() # summing the null values
# Out:
# ID                           0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# End_Lat                      0
# End_Lng                      0
# Distance(mi)                 0
# Description                  0
# Number                    9584
# Street                       0
# Side                         0
# City                         0
# County                       0
# State                        0
# Zipcode                      6
# Country                      1
# Timezone                     7
# Airport_Code                 8
# Weather_Timestamp           92
# Temperature(F)             132
# Wind_Chill(F)            10690
# Humidity(%)                143
# Pressure(in)               127
# Visibility(mi)             166
# Wind_Direction              93
# Wind_Speed(mph)           1875
# Precipitation(in)        10774
# Weather_Condition          134
# ...

# %%
df.isna() #is_any_null in any columns
# Out:
#           ID  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  End_Lat  \
# 0      False     False       False     False      False      False    False
# 1      False     False       False     False      False      False    False
# 2      False     False       False     False      False      False    False
# 3      False     False       False     False      False      False    False
# 4      False     False       False     False      False      False    False
# ...      ...       ...         ...       ...        ...        ...      ...
# 11401  False     False       False     False      False      False    False
# 11402  False     False       False     False      False      False    False
# 11403  False     False       False     False      False      False    False
# 11404  False     False       False     False      False      False    False
# 11405  False     False       False     False      False      False    False
#
# ...

# %% [markdown]
# ### percentage of missing values

# %%
missing_percentage = df.isna().sum().sort_values(ascending = False) # descending order of missing values
missing_percentage
# Out:
# Precipitation(in)        10774
# Wind_Chill(F)            10690
# Number                    9584
# Wind_Speed(mph)           1875
# Visibility(mi)             166
# Humidity(%)                143
# Weather_Condition          134
# Temperature(F)             132
# Pressure(in)               127
# Wind_Direction              93
# Weather_Timestamp           92
# Airport_Code                 8
# Timezone                     7
# Zipcode                      6
# Nautical_Twilight            1
# Civil_Twilight               1
# Sunrise_Sunset               1
# Bump                         1
# Turning_Loop                 1
# Traffic_Calming              1
# Stop                         1
# Crossing                     1
# Amenity                      1
# Junction                     1
# No_Exit                      1
# Railway                      1
# Roundabout                   1
# Traffic_Signal               1
# Station                      1
# Give_Way                     1
# ...

# %%
type(missing_percentage)
# Out:
# pandas.core.series.Series

# %%
missing_percentage.plot(kind = 'barh') # plotting

# %%
# removing zeros from panda series

# %%
missing_percentage != 0
# Out:
# Precipitation(in)         True
# Wind_Chill(F)             True
# Number                    True
# Wind_Speed(mph)           True
# Visibility(mi)            True
# Humidity(%)               True
# Weather_Condition         True
# Temperature(F)            True
# Pressure(in)              True
# Wind_Direction            True
# Weather_Timestamp         True
# Airport_Code              True
# Timezone                  True
# Zipcode                   True
# Nautical_Twilight         True
# Civil_Twilight            True
# Sunrise_Sunset            True
# Bump                      True
# Turning_Loop              True
# Traffic_Calming           True
# Stop                      True
# Crossing                  True
# Amenity                   True
# Junction                  True
# No_Exit                   True
# Railway                   True
# Roundabout                True
# Traffic_Signal            True
# Station                   True
# Give_Way                  True
# ...

# %%
missing_percentage[missing_percentage != 0].plot(kind = 'barh')

# %% [markdown]
# ### Remove columns that don't want to use

# %% [markdown]
# ## Exploratory analysis and visualization
#
# columns need to analysis:
#
# 1.city
#
# 2.Start time
#
# 3.Start lat, Start long
#
# 4.Temperature
#
# 5.Weather conditions

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City
# Out:
# 0             Dublin
# 1             Dayton
# 2         Cincinnati
# 3              Akron
# 4         Cincinnati
#             ...
# 11401          Vista
# 11402    Diamond Bar
# 11403      Oceanside
# 11404       Lawndale
# 11405       Valyermo
# Name: City, Length: 11406, dtype: object

# %%
cities = df.City.unique()  ## uniques values in cities

# %%
len(cities) ## length of the city
# Out:
# 821

# %%
cities_by_accident = df.City.value_counts()

# %%
cities_by_accident
# Out:
# Los Angeles     1016
# Sacramento       398
# San Diego        381
# San Jose         367
# Oakland          190
#                 ...
# San Gregorio       1
# Twain Harte        1
# Carson City        1
# San Martin         1
# San Jacinto        1
# Name: City, Length: 821, dtype: int64

# %%
df.State
# Out:
# 0        OH
# 1        OH
# 2        OH
# 3        OH
# 4        OH
#          ..
# 11401    CA
# 11402    CA
# 11403    CA
# 11404    CA
# 11405    CA
# Name: State, Length: 11406, dtype: object

# %%
'NY' in df.State  ## New York is not mentioned in the datasets
# Out:
# False

# %%
cities_by_accident[:20].plot(kind = 'barh')
